# %%
import sys; sys.path.insert(0, '../')

# %%
import pandas as pd
import matplotlib.pyplot as plt

from src.omni.functions import load_pickle
from src.visualization.exploration import *

# %%
df = pd.read_pickle('../data/sepsis/interim/df.pkl')

# %% [markdown]
# ## Missing Values

# %%
drop_vars = ['hospital', 'Gender', 'ICULOS', 'Age', 'HospAdmTime', 'SepsisLabel', 'id', 'time']   # These are always filled

s_out = missing_values_barplot(df.drop(stationary_vars, axis=1), missing=False, return_vals=True)
